# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

from sklearn.linear_model import LinearRegression

# %%
base_model = pd.read_csv('Resources/Features_Labeled_Categories')

# %%
base_model
# Out:
#       Unnamed: 0                                                App  Rating  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1
# 1              1                                Coloring book moana     3.9
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7
# 3              3                              Sketch - Draw & Paint     4.5
# 4              4              Pixel Draw - Number Art Coloring Book     4.3
# ...          ...                                                ...     ...
# 7718        7718                                        Chemin (fr)     4.8
# 7719        7719                                      FR Calculator     4.0
# 7720        7720                                   Sya9a Maroc - FR     4.5
# 7721        7721                   Fr. Mike Schmitz Audio Teachings     5.0
# 7722        7722      iHoroscope - 2018 Daily Horoscope & Astrology     4.5
#
# ...

# %% [markdown]
# <h3>App by Category Correlations to Rating based on Size, Reviews, Installs

# %% [markdown]
# <h4>Setting Size, Reviews, Installs Variables for Correlation Plots

# %%
family = base_model.loc[base_model.Category=="FAMILY"]
xfam = family.Size
xfamRev = family.Reviews
xfamIns = family.Installs
yfam = family.Rating

game = base_model.loc[base_model.Category=="GAME"]
xgame = game.Size
xgameRev = game.Reviews
xgameIns = game.Installs
ygame = game.Rating

tools = base_model.loc[base_model.Category=="TOOLS"]
xtools = tools.Size
xtoolsRev = tools.Reviews
xtoolsIns = tools.Installs
ytools = tools.Rating

medical = base_model.loc[base_model.Category=="MEDICAL"]
xmed = medical.Size
xmedRev = medical.Reviews
xmedIns = medical.Installs
ymed = medical.Rating

lifestyle = base_model.loc[base_model.Category=="LIFESTYLE"]
xlife = lifestyle.Size
xlifeRev = lifestyle.Reviews
xlifeIns = lifestyle.Installs
ylife = lifestyle.Rating

personalization = base_model.loc[base_model.Category=="PERSONALIZATION"]
xpers = personalization.Size
xpersRev = personalization.Reviews
xpersIns = personalization.Installs
ypers = personalization.Rating

finance = base_model.loc[base_model.Category=="FINANCE"]
xfin = finance.Size
xfinRev = finance.Reviews
xfinIns = finance.Installs
yfin = finance.Rating

sports = base_model.loc[base_model.Category=="SPORTS"]
xsports = sports.Size
xsportsRev = sports.Reviews
xsportsIns = sports.Installs
ysports = sports.Rating

business = base_model.loc[base_model.Category=="BUSINESS"]
xbusiness = business.Size
xbusinessRev = business.Reviews
xbusinessIns = business.Installs
ybusiness = business.Rating

photography = base_model.loc[base_model.Category=="PHOTOGRAPHY"]
xphotography = photography.Size
xphotographyRev = photography.Reviews
xphotographyIns = photography.Installs
yphotography = photography.Rating

productivity = base_model.loc[base_model.Category=="PRODUCTIVITY"]
xproductivity = productivity.Size
xproductivityRev = productivity.Reviews
xproductivityIns = productivity.Installs
yproductivity = productivity.Rating

health = base_model.loc[base_model.Category=="HEALTH_AND_FITNESS"]
xhealth = health.Size
xhealthRev = health.Reviews
xhealthIns = health.Installs
yhealth = health.Rating

communication = base_model.loc[base_model.Category=="COMMUNICATION"]
xcomm = communication.Size
xcommRev = communication.Reviews
xcommIns = communication.Installs
ycomm= communication.Rating

shopping = base_model.loc[base_model.Category=="SHOPPING"]
xshop = shopping.Size
xshopRev = shopping.Reviews
xshopIns = shopping.Installs
yshop = shopping.Rating

social = base_model.loc[base_model.Category=="SOCIAL"]
xsocial = social.Size
xsocialRev = social.Reviews
xsocialIns = social.Installs
ysocial = social.Rating

dating = base_model.loc[base_model.Category=="DATING"]
xdate = dating.Size
xdateRev = dating.Reviews
xdateIns = dating.Installs
ydate = dating.Rating

news = base_model.loc[base_model.Category=="NEWS_AND_MAGAZINES"]
xnews = news.Size
xnewsRev = news.Reviews
xnewsIns = news.Installs
ynews = news.Rating

travel = base_model.loc[base_model.Category=="TRAVEL_AND_LOCAL"]
xtravel = travel.Size
xtravelRev = travel.Reviews
xtravelIns = travel.Installs
ytravel = travel.Rating

books = base_model.loc[base_model.Category=="BOOKS_AND_REFERENCE"]
xbooks = books.Size
xbooksRev = books.Reviews
xbooksIns = books.Installs
ybooks = books.Rating

video = base_model.loc[base_model.Category=="VIDEO_PLAYERS"]
xvideo = video.Size
xvideoRev = video.Reviews
xvideoIns = video.Installs
yvideo = video.Rating

education = base_model.loc[base_model.Category=="EDUCATION"]
xedu = education.Size
xeduRev = education.Reviews
xeduIns = education.Installs
yedu = education.Rating

maps = base_model.loc[base_model.Category=="MAPS_AND_NAVIGATION"]
xmaps = maps.Size
xmapsRev = maps.Reviews
xmapsIns = maps.Installs
ymaps = maps.Rating

entertainment = base_model.loc[base_model.Category=="ENTERTAINMENT"]
xent = entertainment.Size
xentRev = entertainment.Reviews
xentIns = entertainment.Installs
yent = entertainment.Rating

food = base_model.loc[base_model.Category=="FOOD_AND_DRINK"]
xfood = food.Size
xfoodRev = food.Reviews
xfoodIns = food.Installs
yfood = food.Rating

auto = base_model.loc[base_model.Category=="AUTO_AND_VEHICLES"]
xauto = auto.Size
xautoRev = auto.Reviews
xautoIns = auto.Installs
yauto = auto.Rating

library = base_model.loc[base_model.Category=="LIBRARIES_AND_DEMO"]
xlibrary = library.Size
xlibraryRev = library.Reviews
xlibraryIns = library.Installs
ylibrary = library.Rating

art = base_model.loc[base_model.Category=="ART_AND_DESIGN"]
xart = art.Size
xartRev = art.Reviews
xartIns = art.Installs
yart = art.Rating

house = base_model.loc[base_model.Category=="HOUSE_AND_HOME"]
xhouse = house.Size
xhouseRev = house.Reviews
xhouseIns = house.Installs
yhouse = house.Rating

weather = base_model.loc[base_model.Category=="WEATHER"]
xweather = weather.Size
xweatherRev = weather.Reviews
xweatherIns = weather.Installs
yweather = weather.Rating

comic = base_model.loc[base_model.Category=="COMICS"]
xcomic = comic.Size
xcomicRev = comic.Reviews
xcomicIns = comic.Installs
ycomic = comic.Rating

parent = base_model.loc[base_model.Category=="PARENTING"]
xparent = parent.Size
xparentRev = parent.Reviews
xparentIns = parent.Installs
yparent = parent.Rating

event = base_model.loc[base_model.Category=="EVENTS"]
xevent = event.Size
xeventRev = event.Reviews
xeventIns = event.Installs
yevent = event.Rating

beauty = base_model.loc[base_model.Category=="BEAUTY"]
xbeauty = beauty.Size
xbeautyRev = beauty.Reviews
xbeautyIns = beauty.Installs
ybeauty = beauty.Rating

# %% [markdown]
# <h3>Categories (33)

# %% [markdown]
# <h4>Size Correlations by Category

# %%
f,ax=plt.subplots(11,3,figsize=(18,57))

ax[0,0].scatter(xfam,yfam, color = 'blue')
ax[0,0].set_title("(Family) App Size v Rating")
ax[0,0].set_xlabel("App Size")
ax[0,0].set_ylabel("App Rating")
correlationFam = st.pearsonr(xfam,yfam)
m, b = np.polyfit(xfam, yfam, 1)
ax[0,0].plot(xfam, m*xfam + b)
line_eq_Fam = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationFam[0],2)))
print("The linear regression line equation is " + line_eq_Fam)

ax[0,1].scatter(xgame,ygame, color = 'blue')
ax[0,1].set_title("(Game) App Size v Rating")
ax[0,1].set_xlabel("App Size")
ax[0,1].set_ylabel("App Rating")
correlationGame = st.pearsonr(xgame,ygame)
m, b = np.polyfit(xgame, ygame, 1)
ax[0,1].plot(xgame, m*xgame + b)
line_eq_game = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationGame[0],2)))
print("The linear regression line equation is " + line_eq_game)

ax[0,2].scatter(xtools,ytools, color = 'blue')
ax[0,2].set_title("(Tools) App Size v Rating")
ax[0,2].set_xlabel("App Size")
ax[0,2].set_ylabel("App Rating")
correlationTools = st.pearsonr(xtools,ytools)
m, b = np.polyfit(xtools, ytools, 1)
ax[0,2].plot(xtools, m*xtools + b)
line_eq_tools = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationTools[0],2)))
print("The linear regression line equation is " + line_eq_tools)


ax[1,0].scatter(xmed,ymed, color = 'blue')
ax[1,0].set_title("(Medical) App Size v Rating")
ax[1,0].set_xlabel("App Size")
ax[1,0].set_ylabel("App Rating")
correlationMed = st.pearsonr(xmed,ymed)
m, b = np.polyfit(xmed, ymed, 1)
ax[1,0].plot(xmed, m*xmed + b)
line_eq_Med = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationMed[0],2)))
print("The linear regression line equation is " + line_eq_Med)

ax[1,1].scatter(xlife,ylife, color = 'blue')
ax[1,1].set_title("(Lifestyle) App Size v Rating")
ax[1,1].set_xlabel("App Size")
ax[1,1].set_ylabel("App Rating")
correlationLife = st.pearsonr(xlife,ylife)
m, b = np.polyfit(xlife, ylife, 1)
ax[1,1].plot(xlife, m*xlife + b)
line_eq_Life = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationLife[0],2)))
print("The linear regression line equation is " + line_eq_Life)

ax[1,2].scatter(xpers,ypers, color = 'blue')
ax[1,2].set_title("(Personalization) App Size v Rating")
ax[1,2].set_xlabel("App Size")
ax[1,2].set_ylabel("App Rating")
correlationPers = st.pearsonr(xpers,ypers)
m, b = np.polyfit(xpers, ypers, 1)
ax[1,2].plot(xpers, m*xpers + b)
line_eq_pers = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationPers[0],2)))
print("The linear regression line equation is " + line_eq_pers)


ax[2,0].scatter(xfin,yfin, color = 'blue')
ax[2,0].set_title("(Finance) App Size v Rating")
ax[2,0].set_xlabel("App Size")
ax[2,0].set_ylabel("App Rating")
correlationFin = st.pearsonr(xfin,yfin)
m, b = np.polyfit(xfin, yfin, 1)
ax[2,0].plot(xfin, m*xfin + b)
line_eq_Fin = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationFin[0],2)))
print("The linear regression line equation is " + line_eq_Fin)

ax[2,1].scatter(xsports,ysports, color = 'blue')
ax[2,1].set_title("(Sports) App Size v Rating")
ax[2,1].set_xlabel("App Size")
ax[2,1].set_ylabel("App Rating")
correlationSports = st.pearsonr(xsports,ysports)
m, b = np.polyfit(xsports, ysports, 1)
ax[2,1].plot(xsports, m*xsports + b)
line_eq_Sports = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationSports[0],2)))
print("The linear regression line equation is " + line_eq_Sports)

ax[2,2].scatter(xbusiness,ybusiness, color = 'blue')
ax[2,2].set_title("(Business) App Size v Rating")
ax[2,2].set_xlabel("App Size")
ax[2,2].set_ylabel("App Rating")
correlationBusiness = st.pearsonr(xbusiness,ybusiness)
m, b = np.polyfit(xbusiness, ybusiness, 1)
ax[2,2].plot(xbusiness, m*xbusiness + b)
line_eq_business = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationBusiness[0],2)))
print("The linear regression line equation is " + line_eq_business)


ax[3,0].scatter(xphotography,yphotography, color = 'blue')
ax[3,0].set_title("(Photography) App Size v Rating")
ax[3,0].set_xlabel("App Size")
ax[3,0].set_ylabel("App Rating")
correlationPhoto = st.pearsonr(xphotography,yphotography)
m, b = np.polyfit(xphotography, yphotography, 1)
ax[3,0].plot(xphotography, m*xphotography + b)
line_eq_Photo = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationPhoto[0],2)))
print("The linear regression line equation is " + line_eq_Photo)

ax[3,1].scatter(xproductivity,yproductivity, color = 'blue')
ax[3,1].set_title("(Productivity) App Size v Rating")
ax[3,1].set_xlabel("App Size")
ax[3,1].set_ylabel("App Rating")
correlationProductivity = st.pearsonr(xproductivity,yproductivity)
m, b = np.polyfit(xproductivity, yproductivity, 1)
ax[3,1].plot(xproductivity, m*xproductivity + b)
line_eq_Productivity = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationProductivity[0],2)))
print("The linear regression line equation is " + line_eq_Productivity)

ax[3,2].scatter(xhealth,yhealth, color = 'blue')
ax[3,2].set_title("(Health) App Size v Rating")
ax[3,2].set_xlabel("App Size")
ax[3,2].set_ylabel("App Rating")
correlationHealth = st.pearsonr(xhealth,yhealth)
m, b = np.polyfit(xhealth, yhealth, 1)
ax[3,2].plot(xhealth, m*xhealth + b)
line_eq_health = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationHealth[0],2)))
print("The linear regression line equation is " + line_eq_health)


ax[4,0].scatter(xcomm,ycomm, color = 'blue')
ax[4,0].set_title("(Communication) App Size v Rating")
ax[4,0].set_xlabel("App Size")
ax[4,0].set_ylabel("App Rating")
correlationComm = st.pearsonr(xcomm,ycomm)
m, b = np.polyfit(xcomm, ycomm, 1)
ax[4,0].plot(xcomm, m*xcomm + b)
line_eq_Comm = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationComm[0],2)))
print("The linear regression line equation is " + line_eq_Comm)

ax[4,1].scatter(xshop,yshop, color = 'blue')
ax[4,1].set_title("(Shopping) App Size v Rating")
ax[4,1].set_xlabel("App Size")
ax[4,1].set_ylabel("App Rating")
correlationShop = st.pearsonr(xshop,yshop)
m, b = np.polyfit(xshop, yshop, 1)
ax[4,1].plot(xshop, m*xshop + b)
line_eq_Shop = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationShop[0],2)))
print("The linear regression line equation is " + line_eq_Shop)

ax[4,2].scatter(xsocial,ysocial, color = 'blue')
ax[4,2].set_title("(Social) App Size v Rating")
ax[4,2].set_xlabel("App Size")
ax[4,2].set_ylabel("App Rating")
correlationSocial = st.pearsonr(xsocial,ysocial)
m, b = np.polyfit(xsocial, ysocial, 1)
ax[4,2].plot(xsocial, m*xsocial + b)
line_eq_social = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationSocial[0],2)))
print("The linear regression line equation is " + line_eq_social)


ax[5,0].scatter(xdate,ydate, color = 'blue')
ax[5,0].set_title("(Date) App Size v Rating")
ax[5,0].set_xlabel("App Size")
ax[5,0].set_ylabel("App Rating")
correlationDate = st.pearsonr(xdate,ydate)
m, b = np.polyfit(xdate, ydate, 1)
ax[5,0].plot(xdate, m*xdate + b)
line_eq_Date = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationDate[0],2)))
print("The linear regression line equation is " + line_eq_Date)

ax[5,1].scatter(xnews,ynews, color = 'blue')
ax[5,1].set_title("(News) App Size v Rating")
ax[5,1].set_xlabel("App Size")
ax[5,1].set_ylabel("App Rating")
correlationNews = st.pearsonr(xnews,ynews)
m, b = np.polyfit(xnews, ynews, 1)
ax[5,1].plot(xnews, m*xnews + b)
line_eq_News = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationNews[0],2)))
print("The linear regression line equation is " + line_eq_News)

ax[5,2].scatter(xtravel,ytravel, color = 'blue')
ax[5,2].set_title("(Travel) App Size v Rating")
ax[5,2].set_xlabel("App Size")
ax[5,2].set_ylabel("App Rating")
correlationTravel = st.pearsonr(xtravel,ytravel)
m, b = np.polyfit(xtravel, ytravel, 1)
ax[5,2].plot(xtravel, m*xtravel + b)
line_eq_travel = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationTravel[0],2)))
print("The linear regression line equation is " + line_eq_travel)


ax[6,0].scatter(xbooks,ybooks, color = 'blue')
ax[6,0].set_title("(Books) App Size v Rating")
ax[6,0].set_xlabel("App Size")
ax[6,0].set_ylabel("App Rating")
correlationBooks = st.pearsonr(xbooks,ybooks)
m, b = np.polyfit(xbooks, ybooks, 1)
ax[6,0].plot(xbooks, m*xbooks + b)
line_eq_Books = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationBooks[0],2)))
print("The linear regression line equation is " + line_eq_Books)

ax[6,1].scatter(xvideo,yvideo, color = 'blue')
ax[6,1].set_title("(Video Players) App Size v Rating")
ax[6,1].set_xlabel("App Size")
ax[6,1].set_ylabel("App Rating")
correlationVideo = st.pearsonr(xvideo,yvideo)
m, b = np.polyfit(xvideo, yvideo, 1)
ax[6,1].plot(xvideo, m*xvideo + b)
line_eq_Video = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationVideo[0],2)))
print("The linear regression line equation is " + line_eq_Video)

ax[6,2].scatter(xedu,yedu, color = 'blue')
ax[6,2].set_title("(Education) App Size v Rating")
ax[6,2].set_xlabel("App Size")
ax[6,2].set_ylabel("App Rating")
correlationEdu = st.pearsonr(xedu,yedu)
m, b = np.polyfit(xedu, yedu, 1)
ax[6,2].plot(xedu, m*xedu + b)
line_eq_Edu = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationEdu[0],2)))
print("The linear regression line equation is " + line_eq_Edu)


ax[7,0].scatter(xmaps,ymaps, color = 'blue')
ax[7,0].set_title("(Maps and Navigation) App Size v Rating")
ax[7,0].set_xlabel("App Size")
ax[7,0].set_ylabel("App Rating")
correlationMaps = st.pearsonr(xmaps,ymaps)
m, b = np.polyfit(xmaps, ymaps, 1)
ax[7,0].plot(xmaps, m*xmaps + b)
line_eq_Maps = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationMaps[0],2)))
print("The linear regression line equation is " + line_eq_Maps)

ax[7,1].scatter(xent,yent, color = 'blue')
ax[7,1].set_title("(Entertainment) App Size v Rating")
ax[7,1].set_xlabel("App Size")
ax[7,1].set_ylabel("App Rating")
correlationEntertainment = st.pearsonr(xent,yent)
m, b = np.polyfit(xent, yent, 1)
ax[7,1].plot(xent, m*xent + b)
line_eq_Entertainment = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationEntertainment[0],2)))
print("The linear regression line equation is " + line_eq_Entertainment)

ax[7,2].scatter(xfood,yfood, color = 'blue')
ax[7,2].set_title("(Food and Drink)) App Size v Rating")
ax[7,2].set_xlabel("App Size")
ax[7,2].set_ylabel("App Rating")
correlationFood = st.pearsonr(xfood,yfood)
m, b = np.polyfit(xfood, yfood, 1)
ax[7,2].plot(xfood, m*xfood + b)
line_eq_Food = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationFood[0],2)))
print("The linear regression line equation is " + line_eq_Food)


ax[8,0].scatter(xauto,yauto, color = 'blue')
ax[8,0].set_title("(Auto and Vehicles) App Size v Rating")
ax[8,0].set_xlabel("App Size")
ax[8,0].set_ylabel("App Rating")
correlationAuto = st.pearsonr(xauto,yauto)
m, b = np.polyfit(xauto, yauto, 1)
ax[8,0].plot(xauto, m*xauto + b)
line_eq_Auto = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationAuto[0],2)))
print("The linear regression line equation is " + line_eq_Auto)

ax[8,1].scatter(xlibrary,ylibrary, color = 'blue')
ax[8,1].set_title("(Libraries and Demo) App Size v Rating")
ax[8,1].set_xlabel("App Size")
ax[8,1].set_ylabel("App Rating")
correlationLibrary = st.pearsonr(xlibrary,ylibrary)
m, b = np.polyfit(xlibrary, ylibrary, 1)
ax[8,1].plot(xlibrary, m*xlibrary + b)
line_eq_Library = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationLibrary[0],2)))
print("The linear regression line equation is " + line_eq_Library)

ax[8,2].scatter(xart,yart, color = 'blue')
ax[8,2].set_title("(Art and Design) App Size v Rating")
ax[8,2].set_xlabel("App Size")
ax[8,2].set_ylabel("App Rating")
correlationArt = st.pearsonr(xart,yart)
m, b = np.polyfit(xart, yart, 1)
ax[8,2].plot(xart, m*xart + b)
line_eq_Art = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationArt[0],2)))
print("The linear regression line equation is " + line_eq_Art)


ax[9,0].scatter(xhouse,yhouse, color = 'blue')
ax[9,0].set_title("(House and Home) App Size v Rating")
ax[9,0].set_xlabel("App Size")
ax[9,0].set_ylabel("App Rating")
correlationHouse = st.pearsonr(xhouse,yhouse)
m, b = np.polyfit(xhouse, yhouse, 1)
ax[9,0].plot(xhouse, m*xhouse + b)
line_eq_House = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationHouse[0],2)))
print("The linear regression line equation is " + line_eq_House)

ax[9,1].scatter(xweather,yweather, color = 'blue')
ax[9,1].set_title("(Weather) App Size v Rating")
ax[9,1].set_xlabel("App Size")
ax[9,1].set_ylabel("App Rating")
correlationWeather = st.pearsonr(xweather,yweather)
m, b = np.polyfit(xweather, yweather, 1)
ax[9,1].plot(xweather, m*xweather + b)
line_eq_Weather = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationWeather[0],2)))
print("The linear regression line equation is " + line_eq_Weather)

ax[9,2].scatter(xcomic,ycomic, color = 'blue')
ax[9,2].set_title("(Comic) App Size v Rating")
ax[9,2].set_xlabel("App Size")
ax[9,2].set_ylabel("App Rating")
correlationComic = st.pearsonr(xcomic,ycomic)
m, b = np.polyfit(xcomic, ycomic, 1)
ax[9,2].plot(xcomic, m*xcomic + b)
line_eq_Comic = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationComic[0],2)))
print("The linear regression line equation is " + line_eq_Comic)


ax[10,0].scatter(xparent,yparent, color = 'blue')
ax[10,0].set_title("(Parenting) App Size v Rating")
ax[10,0].set_xlabel("App Size")
ax[10,0].set_ylabel("App Rating")
correlationParent = st.pearsonr(xparent,yparent)
m, b = np.polyfit(xparent, yparent, 1)
ax[10,0].plot(xparent, m*xparent + b)
line_eq_Parent = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationParent[0],2)))
print("The linear regression line equation is " + line_eq_Parent)

ax[10,1].scatter(xevent,yevent, color = 'blue')
ax[10,1].set_title("(Event) App Size v Rating")
ax[10,1].set_xlabel("App Size")
ax[10,1].set_ylabel("App Rating")
correlationEvent = st.pearsonr(xevent,yevent)
m, b = np.polyfit(xevent, yevent, 1)
ax[10,1].plot(xevent, m*xevent + b)
line_eq_Event = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationEvent[0],2)))
print("The linear regression line equation is " + line_eq_Event)

ax[10,2].scatter(xbeauty,ybeauty, color = 'blue')
ax[10,2].set_title("(Beauty) App Size v Rating")
ax[10,2].set_xlabel("App Size")
ax[10,2].set_ylabel("App Rating")
correlationBeauty = st.pearsonr(xbeauty,ybeauty)
m, b = np.polyfit(xbeauty, ybeauty, 1)
ax[10,2].plot(xbeauty, m*xbeauty + b)
line_eq_Beauty = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationBeauty[0],2)))
print("The linear regression line equation is " + line_eq_Beauty)
# Out:
# The correlation coefficient is 0.08
# The linear regression line equation is y = 0.0x + 4.15
# The correlation coefficient is 0.19
# The linear regression line equation is y = 0.0x + 4.15
# The correlation coefficient is -0.13
# The linear regression line equation is y = -0.0x + 4.07
# The correlation coefficient is 0.03
# The linear regression line equation is y = 0.0x + 4.17
# The correlation coefficient is -0.15
# The linear regression line equation is y = -0.0x + 4.19
# The correlation coefficient is 0.24
# The linear regression line equation is y = 0.0x + 4.25
# The correlation coefficient is -0.02
# The linear regression line equation is y = -0.0x + 4.13
# The correlation coefficient is 0.05
# The linear regression line equation is y = 0.0x + 4.18
# The correlation coefficient is 0.12
# The linear regression line equation is y = 0.0x + 4.04
# The correlation coefficient is 0.23
# The linear regression line equation is y = 0.0x + 4.03
# The correlation coefficient is 0.13
# ...

# %% [markdown]
# <h4>Reviews Correlation by Category

# %%
f,ax=plt.subplots(11,3,figsize=(18,57))

ax[0,0].scatter(xfamRev,yfam, color = 'orange')
ax[0,0].set_title("(Family) App Reviews v Rating")
ax[0,0].set_xlabel("App Reviews")
ax[0,0].set_ylabel("App Rating")
correlationFamRev = st.pearsonr(xfamRev,yfam)
m, b = np.polyfit(xfamRev, yfam, 1)
ax[0,0].plot(xfamRev, m*xfamRev + b)
line_eq_FamRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationFamRev[0],2)))
print("The linear regression line equation is " + line_eq_FamRev)

ax[0,1].scatter(xgameRev,ygame, color = 'orange')
ax[0,1].set_title("(Game) App Reviews v Rating")
ax[0,1].set_xlabel("App Reviews")
ax[0,1].set_ylabel("App Rating")
correlationGameRev = st.pearsonr(xgameRev,ygame)
m, b = np.polyfit(xgameRev, ygame, 1)
ax[0,1].plot(xgameRev, m*xgameRev + b)
line_eq_gameRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationGameRev[0],2)))
print("The linear regression line equation is " + line_eq_gameRev)

ax[0,2].scatter(xtoolsRev,ytools, color = 'orange')
ax[0,2].set_title("(Tools) App Reviews v Rating")
ax[0,2].set_xlabel("App Reviews")
ax[0,2].set_ylabel("App Rating")
correlationToolsRev = st.pearsonr(xtoolsRev,ytools)
m, b = np.polyfit(xtoolsRev, ytools, 1)
ax[0,2].plot(xtoolsRev, m*xtoolsRev + b)
line_eq_toolsRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationToolsRev[0],2)))
print("The linear regression line equation is " + line_eq_toolsRev)


ax[1,0].scatter(xmedRev,ymed, color = 'orange')
ax[1,0].set_title("(Medical) App Reviews v Rating")
ax[1,0].set_xlabel("App Reviews")
ax[1,0].set_ylabel("App Rating")
correlationMedRev = st.pearsonr(xmedRev,ymed)
m, b = np.polyfit(xmedRev, ymed, 1)
ax[1,0].plot(xmedRev, m*xmedRev + b)
line_eq_MedRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationMedRev[0],2)))
print("The linear regression line equation is " + line_eq_MedRev)

ax[1,1].scatter(xlifeRev,ylife, color = 'orange')
ax[1,1].set_title("(Lifestyle) App Reviews v Rating")
ax[1,1].set_xlabel("App Reviews")
ax[1,1].set_ylabel("App Rating")
correlationLifeRev = st.pearsonr(xlifeRev,ylife)
m, b = np.polyfit(xlifeRev, ylife, 1)
ax[1,1].plot(xlifeRev, m*xlifeRev + b)
line_eq_LifeRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationLifeRev[0],2)))
print("The linear regression line equation is " + line_eq_LifeRev)

ax[1,2].scatter(xpersRev,ypers, color = 'orange')
ax[1,2].set_title("(Personalization) App Reviews v Rating")
ax[1,2].set_xlabel("App Reviews")
ax[1,2].set_ylabel("App Rating")
correlationPersRev = st.pearsonr(xpersRev,ypers)
m, b = np.polyfit(xpersRev, ypers, 1)
ax[1,2].plot(xpersRev, m*xpersRev + b)
line_eq_persRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationPersRev[0],2)))
print("The linear regression line equation is " + line_eq_persRev)


ax[2,0].scatter(xfinRev,yfin, color = 'orange')
ax[2,0].set_title("(Finance) App Reviews v Rating")
ax[2,0].set_xlabel("App Reviews")
ax[2,0].set_ylabel("App Rating")
correlationFinRev = st.pearsonr(xfinRev,yfin)
m, b = np.polyfit(xfinRev, yfin, 1)
ax[2,0].plot(xfinRev, m*xfinRev + b)
line_eq_FinRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationFinRev[0],2)))
print("The linear regression line equation is " + line_eq_FinRev)

ax[2,1].scatter(xsportsRev,ysports, color = 'orange')
ax[2,1].set_title("(Sports) App Reviews v Rating")
ax[2,1].set_xlabel("App Reviews")
ax[2,1].set_ylabel("App Rating")
correlationSportsRev = st.pearsonr(xsportsRev,ysports)
m, b = np.polyfit(xsportsRev, ysports, 1)
ax[2,1].plot(xsportsRev, m*xsportsRev + b)
line_eq_SportsRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationSportsRev[0],2)))
print("The linear regression line equation is " + line_eq_SportsRev)

ax[2,2].scatter(xbusinessRev,ybusiness, color = 'orange')
ax[2,2].set_title("(Business) App Reviews v Rating")
ax[2,2].set_xlabel("App Reviews")
ax[2,2].set_ylabel("App Rating")
correlationBusinessRev = st.pearsonr(xbusinessRev,ybusiness)
m, b = np.polyfit(xbusinessRev, ybusiness, 1)
ax[2,2].plot(xbusinessRev, m*xbusinessRev + b)
line_eq_businessRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationBusinessRev[0],2)))
print("The linear regression line equation is " + line_eq_businessRev)


ax[3,0].scatter(xphotographyRev,yphotography, color = 'orange')
ax[3,0].set_title("(Photography) App Reviews v Rating")
ax[3,0].set_xlabel("App Reviews")
ax[3,0].set_ylabel("App Rating")
correlationPhotoRev = st.pearsonr(xphotographyRev,yphotography)
m, b = np.polyfit(xphotographyRev, yphotography, 1)
ax[3,0].plot(xphotographyRev, m*xphotographyRev + b)
line_eq_PhotoRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationPhotoRev[0],2)))
print("The linear regression line equation is " + line_eq_PhotoRev)

ax[3,1].scatter(xproductivityRev,yproductivity, color = 'orange')
ax[3,1].set_title("(Productivity) App Reviews v Rating")
ax[3,1].set_xlabel("App Reviews")
ax[3,1].set_ylabel("App Rating")
correlationProductivityRev = st.pearsonr(xproductivityRev,yproductivity)
m, b = np.polyfit(xproductivityRev, yproductivity, 1)
ax[3,1].plot(xproductivityRev, m*xproductivityRev + b)
line_eq_ProductivityRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationProductivityRev[0],2)))
print("The linear regression line equation is " + line_eq_ProductivityRev)

ax[3,2].scatter(xhealthRev,yhealth, color = 'orange')
ax[3,2].set_title("(Health) App Reviews v Rating")
ax[3,2].set_xlabel("App Reviews")
ax[3,2].set_ylabel("App Rating")
correlationHealthRev = st.pearsonr(xhealthRev,yhealth)
m, b = np.polyfit(xhealthRev, yhealth, 1)
ax[3,2].plot(xhealthRev, m*xhealthRev + b)
line_eq_healthRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationHealthRev[0],2)))
print("The linear regression line equation is " + line_eq_healthRev)


ax[4,0].scatter(xcommRev,ycomm, color = 'orange')
ax[4,0].set_title("(Communication) App Reviews v Rating")
ax[4,0].set_xlabel("App Reviews")
ax[4,0].set_ylabel("App Rating")
correlationCommRev = st.pearsonr(xcommRev,ycomm)
m, b = np.polyfit(xcommRev, ycomm, 1)
ax[4,0].plot(xcommRev, m*xcommRev + b)
line_eq_CommRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationCommRev[0],2)))
print("The linear regression line equation is " + line_eq_CommRev)

ax[4,1].scatter(xshopRev,yshop, color = 'orange')
ax[4,1].set_title("(Shopping) App Reviews v Rating")
ax[4,1].set_xlabel("App Reviews")
ax[4,1].set_ylabel("App Rating")
correlationShopRev = st.pearsonr(xshopRev,yshop)
m, b = np.polyfit(xshopRev, yshop, 1)
ax[4,1].plot(xshopRev, m*xshopRev + b)
line_eq_ShopRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationShopRev[0],2)))
print("The linear regression line equation is " + line_eq_ShopRev)

ax[4,2].scatter(xsocialRev,ysocial, color = 'orange')
ax[4,2].set_title("(Social) App Reviews v Rating")
ax[4,2].set_xlabel("App Reviews")
ax[4,2].set_ylabel("App Rating")
correlationSocialRev = st.pearsonr(xsocialRev,ysocial)
m, b = np.polyfit(xsocialRev, ysocial, 1)
ax[4,2].plot(xsocialRev, m*xsocialRev + b)
line_eq_socialRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationSocialRev[0],2)))
print("The linear regression line equation is " + line_eq_socialRev)


ax[5,0].scatter(xdateRev,ydate, color = 'orange')
ax[5,0].set_title("(Date) App Reviews v Rating")
ax[5,0].set_xlabel("App Reviews")
ax[5,0].set_ylabel("App Rating")
correlationDateRev = st.pearsonr(xdateRev,ydate)
m, b = np.polyfit(xdateRev, ydate, 1)
ax[5,0].plot(xdateRev, m*xdateRev + b)
line_eq_DateRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationDateRev[0],2)))
print("The linear regression line equation is " + line_eq_DateRev)

ax[5,1].scatter(xnewsRev,ynews, color = 'orange')
ax[5,1].set_title("(News) App Reviews v Rating")
ax[5,1].set_xlabel("App Reviews")
ax[5,1].set_ylabel("App Rating")
correlationNewsRev = st.pearsonr(xnewsRev,ynews)
m, b = np.polyfit(xnewsRev, ynews, 1)
ax[5,1].plot(xnewsRev, m*xnewsRev + b)
line_eq_NewsRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationNewsRev[0],2)))
print("The linear regression line equation is " + line_eq_NewsRev)

ax[5,2].scatter(xtravelRev,ytravel, color = 'orange')
ax[5,2].set_title("(Travel) App Reviews v Rating")
ax[5,2].set_xlabel("App Reviews")
ax[5,2].set_ylabel("App Rating")
correlationTravelRev = st.pearsonr(xtravelRev,ytravel)
m, b = np.polyfit(xtravelRev, ytravel, 1)
ax[5,2].plot(xtravelRev, m*xtravelRev + b)
line_eq_travelRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationTravelRev[0],2)))
print("The linear regression line equation is " + line_eq_travelRev)


ax[6,0].scatter(xbooksRev,ybooks, color = 'orange')
ax[6,0].set_title("(Books) App Reviews v Rating")
ax[6,0].set_xlabel("App Reviews")
ax[6,0].set_ylabel("App Rating")
correlationBooksRev = st.pearsonr(xbooksRev,ybooks)
m, b = np.polyfit(xbooksRev, ybooks, 1)
ax[6,0].plot(xbooksRev, m*xbooksRev + b)
line_eq_BooksRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationBooksRev[0],2)))
print("The linear regression line equation is " + line_eq_BooksRev)

ax[6,1].scatter(xvideoRev,yvideo, color = 'orange')
ax[6,1].set_title("(Video Players) App Reviews v Rating")
ax[6,1].set_xlabel("App Reviews")
ax[6,1].set_ylabel("App Rating")
correlationVideoRev = st.pearsonr(xvideoRev,yvideo)
m, b = np.polyfit(xvideoRev, yvideo, 1)
ax[6,1].plot(xvideoRev, m*xvideoRev + b)
line_eq_VideoRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationVideoRev[0],2)))
print("The linear regression line equation is " + line_eq_VideoRev)

ax[6,2].scatter(xeduRev,yedu, color = 'orange')
ax[6,2].set_title("(Education) App Reviews v Rating")
ax[6,2].set_xlabel("App Reviews")
ax[6,2].set_ylabel("App Rating")
correlationEduRev = st.pearsonr(xeduRev,yedu)
m, b = np.polyfit(xeduRev, yedu, 1)
ax[6,2].plot(xeduRev, m*xeduRev + b)
line_eq_EduRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationEduRev[0],2)))
print("The linear regression line equation is " + line_eq_EduRev)


ax[7,0].scatter(xmapsRev,ymaps, color = 'orange')
ax[7,0].set_title("(Maps and Navigation) App Reviews v Rating")
ax[7,0].set_xlabel("App Reviews")
ax[7,0].set_ylabel("App Rating")
correlationMapsRev = st.pearsonr(xmapsRev,ymaps)
m, b = np.polyfit(xmapsRev, ymaps, 1)
ax[7,0].plot(xmapsRev, m*xmapsRev + b)
line_eq_MapsRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationMapsRev[0],2)))
print("The linear regression line equation is " + line_eq_MapsRev)

ax[7,1].scatter(xentRev,yent, color = 'orange')
ax[7,1].set_title("(Entertainment) App Reviews v Rating")
ax[7,1].set_xlabel("App Reviews")
ax[7,1].set_ylabel("App Rating")
correlationEntertainmentRev = st.pearsonr(xentRev,yent)
m, b = np.polyfit(xentRev, yent, 1)
ax[7,1].plot(xentRev, m*xentRev + b)
line_eq_EntertainmentRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationEntertainmentRev[0],2)))
print("The linear regression line equation is " + line_eq_EntertainmentRev)

ax[7,2].scatter(xfoodRev,yfood, color = 'orange')
ax[7,2].set_title("(Food and Drink)) App Reviews v Rating")
ax[7,2].set_xlabel("App Reviews")
ax[7,2].set_ylabel("App Rating")
correlationFoodRev = st.pearsonr(xfoodRev,yfood)
m, b = np.polyfit(xfoodRev, yfood, 1)
ax[7,2].plot(xfoodRev, m*xfoodRev + b)
line_eq_FoodRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationFoodRev[0],2)))
print("The linear regression line equation is " + line_eq_FoodRev)


ax[8,0].scatter(xautoRev,yauto, color = 'orange')
ax[8,0].set_title("(Auto and Vehicles) App Reviews v Rating")
ax[8,0].set_xlabel("App Reviews")
ax[8,0].set_ylabel("App Rating")
correlationAutoRev = st.pearsonr(xautoRev,yauto)
m, b = np.polyfit(xautoRev, yauto, 1)
ax[8,0].plot(xautoRev, m*xautoRev + b)
line_eq_AutoRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationAutoRev[0],2)))
print("The linear regression line equation is " + line_eq_AutoRev)

ax[8,1].scatter(xlibraryRev,ylibrary, color = 'orange')
ax[8,1].set_title("(Libraries and Demo) App Reviews v Rating")
ax[8,1].set_xlabel("App Reviews")
ax[8,1].set_ylabel("App Rating")
correlationLibraryRev = st.pearsonr(xlibraryRev,ylibrary)
m, b = np.polyfit(xlibraryRev, ylibrary, 1)
ax[8,1].plot(xlibraryRev, m*xlibraryRev + b)
line_eq_LibraryRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationLibraryRev[0],2)))
print("The linear regression line equation is " + line_eq_LibraryRev)

ax[8,2].scatter(xartRev,yart, color = 'orange')
ax[8,2].set_title("(Art and Design) App Reviews v Rating")
ax[8,2].set_xlabel("App Reviews")
ax[8,2].set_ylabel("App Rating")
correlationArtRev = st.pearsonr(xartRev,yart)
m, b = np.polyfit(xartRev, yart, 1)
ax[8,2].plot(xartRev, m*xartRev + b)
line_eq_ArtRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationArtRev[0],2)))
print("The linear regression line equation is " + line_eq_ArtRev)


ax[9,0].scatter(xhouseRev,yhouse, color = 'orange')
ax[9,0].set_title("(House and Home) App Reviews v Rating")
ax[9,0].set_xlabel("App Reviews")
ax[9,0].set_ylabel("App Rating")
correlationHouseRev = st.pearsonr(xhouseRev,yhouse)
m, b = np.polyfit(xhouseRev, yhouse, 1)
ax[9,0].plot(xhouseRev, m*xhouseRev + b)
line_eq_HouseRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationHouseRev[0],2)))
print("The linear regression line equation is " + line_eq_HouseRev)

ax[9,1].scatter(xweatherRev,yweather, color = 'orange')
ax[9,1].set_title("(Weather) App Reviews v Rating")
ax[9,1].set_xlabel("App Reviews")
ax[9,1].set_ylabel("App Rating")
correlationWeatherRev = st.pearsonr(xweatherRev,yweather)
m, b = np.polyfit(xweatherRev, yweather, 1)
ax[9,1].plot(xweatherRev, m*xweatherRev + b)
line_eq_WeatherRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationWeatherRev[0],2)))
print("The linear regression line equation is " + line_eq_WeatherRev)

ax[9,2].scatter(xcomicRev,ycomic, color = 'orange')
ax[9,2].set_title("(Comic) App Reviews v Rating")
ax[9,2].set_xlabel("App Reviews")
ax[9,2].set_ylabel("App Rating")
correlationComicRev = st.pearsonr(xcomicRev,ycomic)
m, b = np.polyfit(xcomicRev, ycomic, 1)
ax[9,2].plot(xcomicRev, m*xcomicRev + b)
line_eq_ComicRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationComicRev[0],2)))
print("The linear regression line equation is " + line_eq_ComicRev)


ax[10,0].scatter(xparentRev,yparent, color = 'orange')
ax[10,0].set_title("(Parenting) App Reviews v Rating")
ax[10,0].set_xlabel("App Reviews")
ax[10,0].set_ylabel("App Rating")
correlationParentRev = st.pearsonr(xparentRev,yparent)
m, b = np.polyfit(xparentRev, yparent, 1)
ax[10,0].plot(xparentRev, m*xparentRev + b)
line_eq_ParentRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationParentRev[0],2)))
print("The linear regression line equation is " + line_eq_ParentRev)

ax[10,1].scatter(xeventRev,yevent, color = 'orange')
ax[10,1].set_title("(Event) App Reviews v Rating")
ax[10,1].set_xlabel("App Reviews")
ax[10,1].set_ylabel("App Rating")
correlationEventRev = st.pearsonr(xeventRev,yevent)
m, b = np.polyfit(xeventRev, yevent, 1)
ax[10,1].plot(xeventRev, m*xeventRev + b)
line_eq_EventRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationEventRev[0],2)))
print("The linear regression line equation is " + line_eq_EventRev)

ax[10,2].scatter(xbeautyRev,ybeauty, color = 'orange')
ax[10,2].set_title("(Beauty) App Reviews v Rating")
ax[10,2].set_xlabel("App Reviews")
ax[10,2].set_ylabel("App Rating")
correlationBeautyRev = st.pearsonr(xbeautyRev,ybeauty)
m, b = np.polyfit(xbeautyRev, ybeauty, 1)
ax[10,2].plot(xbeautyRev, m*xbeautyRev + b)
line_eq_BeautyRev = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationBeautyRev[0],2)))
print("The linear regression line equation is " + line_eq_BeautyRev)
# Out:
# The correlation coefficient is 0.06
# The linear regression line equation is y = 0.0x + 4.19
# The correlation coefficient is 0.16
# The linear regression line equation is y = 0.0x + 4.25
# The correlation coefficient is 0.11
# The linear regression line equation is y = 0.0x + 4.0
# The correlation coefficient is 0.17
# The linear regression line equation is y = 0.0x + 4.15
# The correlation coefficient is 0.04
# The linear regression line equation is y = 0.0x + 4.09
# The correlation coefficient is 0.1
# The linear regression line equation is y = 0.0x + 4.32
# The correlation coefficient is 0.11
# The linear regression line equation is y = 0.0x + 4.09
# The correlation coefficient is 0.08
# The linear regression line equation is y = 0.0x + 4.2
# The correlation coefficient is 0.09
# The linear regression line equation is y = 0.0x + 4.11
# The correlation coefficient is 0.16
# The linear regression line equation is y = 0.0x + 4.12
# The correlation coefficient is 0.14
# ...

# %% [markdown]
# <h4>Installs Correlation by Category

# %%
f,ax=plt.subplots(11,3,figsize=(18,57))

ax[0,0].scatter(xfamIns,yfam, color = 'red')
ax[0,0].set_title("(Family) App Installs v Rating")
ax[0,0].set_xlabel("App Installs")
ax[0,0].set_ylabel("App Rating")
correlationFamIns = st.pearsonr(xfamIns,yfam)
m, b = np.polyfit(xfamIns, yfam, 1)
ax[0,0].plot(xfamIns, m*xfamRev + b)
line_eq_FamIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationFamIns[0],2)))
print("The linear regression line equation is " + line_eq_FamIns)

ax[0,1].scatter(xgameIns,ygame, color = 'red')
ax[0,1].set_title("(Game) App Installs v Rating")
ax[0,1].set_xlabel("App Installs")
ax[0,1].set_ylabel("App Rating")
correlationGameIns = st.pearsonr(xgameIns,ygame)
m, b = np.polyfit(xgameIns, ygame, 1)
ax[0,1].plot(xgameIns, m*xgameIns + b)
line_eq_gameIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationGameIns[0],2)))
print("The linear regression line equation is " + line_eq_gameIns)

ax[0,2].scatter(xtoolsIns,ytools, color = 'red')
ax[0,2].set_title("(Tools) App Installs v Rating")
ax[0,2].set_xlabel("App Installs")
ax[0,2].set_ylabel("App Rating")
correlationToolsIns = st.pearsonr(xtoolsIns,ytools)
m, b = np.polyfit(xtoolsIns, ytools, 1)
ax[0,2].plot(xtoolsIns, m*xtoolsIns + b)
line_eq_toolsIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationToolsIns[0],2)))
print("The linear regression line equation is " + line_eq_toolsIns)


ax[1,0].scatter(xmedIns,ymed, color = 'red')
ax[1,0].set_title("(Medical) App Installs v Rating")
ax[1,0].set_xlabel("App Installs")
ax[1,0].set_ylabel("App Rating")
correlationMedIns = st.pearsonr(xmedIns,ymed)
m, b = np.polyfit(xmedIns, ymed, 1)
ax[1,0].plot(xmedIns, m*xmedIns + b)
line_eq_MedIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationMedIns[0],2)))
print("The linear regression line equation is " + line_eq_MedIns)

ax[1,1].scatter(xlifeIns,ylife, color = 'red')
ax[1,1].set_title("(Lifestyle) App Installs v Rating")
ax[1,1].set_xlabel("App Installs")
ax[1,1].set_ylabel("App Rating")
correlationLifeIns = st.pearsonr(xlifeIns,ylife)
m, b = np.polyfit(xlifeIns, ylife, 1)
ax[1,1].plot(xlifeIns, m*xlifeIns + b)
line_eq_LifeIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationLifeIns[0],2)))
print("The linear regression line equation is " + line_eq_LifeIns)

ax[1,2].scatter(xpersIns,ypers, color = 'red')
ax[1,2].set_title("(Personalization) App Installs v Rating")
ax[1,2].set_xlabel("App Installs")
ax[1,2].set_ylabel("App Rating")
correlationPersIns = st.pearsonr(xpersIns,ypers)
m, b = np.polyfit(xpersIns, ypers, 1)
ax[1,2].plot(xpersIns, m*xpersIns + b)
line_eq_persIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationPersIns[0],2)))
print("The linear regression line equation is " + line_eq_persIns)


ax[2,0].scatter(xfinIns,yfin, color = 'red')
ax[2,0].set_title("(Finance) App Installs v Rating")
ax[2,0].set_xlabel("App Installs")
ax[2,0].set_ylabel("App Rating")
correlationFinIns = st.pearsonr(xfinIns,yfin)
m, b = np.polyfit(xfinIns, yfin, 1)
ax[2,0].plot(xfinIns, m*xfinIns + b)
line_eq_FinIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationFinIns[0],2)))
print("The linear regression line equation is " + line_eq_FinIns)

ax[2,1].scatter(xsportsIns,ysports, color = 'red')
ax[2,1].set_title("(Sports) App Installs v Rating")
ax[2,1].set_xlabel("App Installs")
ax[2,1].set_ylabel("App Rating")
correlationSportsIns = st.pearsonr(xsportsIns,ysports)
m, b = np.polyfit(xsportsIns, ysports, 1)
ax[2,1].plot(xsportsIns, m*xsportsIns + b)
line_eq_SportsIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationSportsIns[0],2)))
print("The linear regression line equation is " + line_eq_SportsIns)

ax[2,2].scatter(xbusinessIns,ybusiness, color = 'red')
ax[2,2].set_title("(Business) App Installs v Rating")
ax[2,2].set_xlabel("App Installs")
ax[2,2].set_ylabel("App Rating")
correlationBusinessIns = st.pearsonr(xbusinessIns,ybusiness)
m, b = np.polyfit(xbusinessIns, ybusiness, 1)
ax[2,2].plot(xbusinessIns, m*xbusinessIns + b)
line_eq_businessIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationBusinessIns[0],2)))
print("The linear regression line equation is " + line_eq_businessIns)


ax[3,0].scatter(xphotographyIns,yphotography, color = 'red')
ax[3,0].set_title("(Photography) App Installs v Rating")
ax[3,0].set_xlabel("App Installs")
ax[3,0].set_ylabel("App Rating")
correlationPhotoIns = st.pearsonr(xphotographyIns,yphotography)
m, b = np.polyfit(xphotographyIns, yphotography, 1)
ax[3,0].plot(xphotographyIns, m*xphotographyIns + b)
line_eq_PhotoIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationPhotoIns[0],2)))
print("The linear regression line equation is " + line_eq_PhotoIns)

ax[3,1].scatter(xproductivityIns,yproductivity, color = 'red')
ax[3,1].set_title("(Productivity) App Installs v Rating")
ax[3,1].set_xlabel("App Installs")
ax[3,1].set_ylabel("App Rating")
correlationProductivityIns = st.pearsonr(xproductivityIns,yproductivity)
m, b = np.polyfit(xproductivityIns, yproductivity, 1)
ax[3,1].plot(xproductivityIns, m*xproductivityIns + b)
line_eq_ProductivityIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationProductivityIns[0],2)))
print("The linear regression line equation is " + line_eq_ProductivityIns)

ax[3,2].scatter(xhealthRev,yhealth, color = 'red')
ax[3,2].set_title("(Health) App Installs v Rating")
ax[3,2].set_xlabel("App Installs")
ax[3,2].set_ylabel("App Rating")
correlationHealthIns = st.pearsonr(xhealthIns,yhealth)
m, b = np.polyfit(xhealthIns, yhealth, 1)
ax[3,2].plot(xhealthIns, m*xhealthIns + b)
line_eq_healthIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationHealthIns[0],2)))
print("The linear regression line equation is " + line_eq_healthIns)


ax[4,0].scatter(xcommIns,ycomm, color = 'red')
ax[4,0].set_title("(Communication) App Installs v Rating")
ax[4,0].set_xlabel("App Installs")
ax[4,0].set_ylabel("App Rating")
correlationCommIns = st.pearsonr(xcommRev,ycomm)
m, b = np.polyfit(xcommIns, ycomm, 1)
ax[4,0].plot(xcommIns, m*xcommIns + b)
line_eq_CommIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationCommIns[0],2)))
print("The linear regression line equation is " + line_eq_CommIns)

ax[4,1].scatter(xshopIns,yshop, color = 'red')
ax[4,1].set_title("(Shopping) App Installs v Rating")
ax[4,1].set_xlabel("App Installs")
ax[4,1].set_ylabel("App Rating")
correlationShopIns = st.pearsonr(xshopIns,yshop)
m, b = np.polyfit(xshopIns, yshop, 1)
ax[4,1].plot(xshopIns, m*xshopRev + b)
line_eq_ShopIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationShopIns[0],2)))
print("The linear regression line equation is " + line_eq_ShopIns)

ax[4,2].scatter(xsocialIns,ysocial, color = 'red')
ax[4,2].set_title("(Social) App Installs v Rating")
ax[4,2].set_xlabel("App Installs")
ax[4,2].set_ylabel("App Rating")
correlationSocialIns = st.pearsonr(xsocialIns,ysocial)
m, b = np.polyfit(xsocialIns, ysocial, 1)
ax[4,2].plot(xsocialIns, m*xsocialIns + b)
line_eq_socialIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationSocialIns[0],2)))
print("The linear regression line equation is " + line_eq_socialIns)


ax[5,0].scatter(xdateIns,ydate, color = 'red')
ax[5,0].set_title("(Date) App Installs v Rating")
ax[5,0].set_xlabel("App Installs")
ax[5,0].set_ylabel("App Rating")
correlationDateIns = st.pearsonr(xdateIns,ydate)
m, b = np.polyfit(xdateIns, ydate, 1)
ax[5,0].plot(xdateIns, m*xdateIns + b)
line_eq_DateIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationDateIns[0],2)))
print("The linear regression line equation is " + line_eq_DateIns)

ax[5,1].scatter(xnewsIns,ynews, color = 'red')
ax[5,1].set_title("(News) App Installs v Rating")
ax[5,1].set_xlabel("App Installs")
ax[5,1].set_ylabel("App Rating")
correlationNewsIns = st.pearsonr(xnewsIns,ynews)
m, b = np.polyfit(xnewsIns, ynews, 1)
ax[5,1].plot(xnewsIns, m*xnewsRev + b)
line_eq_NewsIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationNewsIns[0],2)))
print("The linear regression line equation is " + line_eq_NewsIns)

ax[5,2].scatter(xtravelIns,ytravel, color = 'red')
ax[5,2].set_title("(Travel) App Installs v Rating")
ax[5,2].set_xlabel("App Installs")
ax[5,2].set_ylabel("App Rating")
correlationTravelIns = st.pearsonr(xtravelIns,ytravel)
m, b = np.polyfit(xtravelIns, ytravel, 1)
ax[5,2].plot(xtravelIns, m*xtravelIns + b)
line_eq_travelIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationTravelIns[0],2)))
print("The linear regression line equation is " + line_eq_travelIns)


ax[6,0].scatter(xbooksIns,ybooks, color = 'red')
ax[6,0].set_title("(Books) App Installs v Rating")
ax[6,0].set_xlabel("App Installs")
ax[6,0].set_ylabel("App Rating")
correlationBooksIns = st.pearsonr(xbooksIns,ybooks)
m, b = np.polyfit(xbooksIns, ybooks, 1)
ax[6,0].plot(xbooksIns, m*xbooksIns + b)
line_eq_BooksIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationBooksIns[0],2)))
print("The linear regression line equation is " + line_eq_BooksIns)

ax[6,1].scatter(xvideoIns,yvideo, color = 'red')
ax[6,1].set_title("(Video Players) App Installs v Rating")
ax[6,1].set_xlabel("App Installs")
ax[6,1].set_ylabel("App Rating")
correlationVideoIns = st.pearsonr(xvideoIns,yvideo)
m, b = np.polyfit(xvideoIns, yvideo, 1)
ax[6,1].plot(xvideoIns, m*xvideoIns + b)
line_eq_VideoIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationVideoIns[0],2)))
print("The linear regression line equation is " + line_eq_VideoIns)

ax[6,2].scatter(xeduIns,yedu, color = 'red')
ax[6,2].set_title("(Education) App Installs v Rating")
ax[6,2].set_xlabel("App Installs")
ax[6,2].set_ylabel("App Rating")
correlationEduIns = st.pearsonr(xeduIns,yedu)
m, b = np.polyfit(xeduIns, yedu, 1)
ax[6,2].plot(xeduIns, m*xeduIns + b)
line_eq_EduIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationEduIns[0],2)))
print("The linear regression line equation is " + line_eq_EduIns)


ax[7,0].scatter(xmapsIns,ymaps, color = 'red')
ax[7,0].set_title("(Maps and Navigation) App Installs v Rating")
ax[7,0].set_xlabel("App Installs")
ax[7,0].set_ylabel("App Rating")
correlationMapsIns = st.pearsonr(xmapsIns,ymaps)
m, b = np.polyfit(xmapsIns, ymaps, 1)
ax[7,0].plot(xmapsIns, m*xmapsIns + b)
line_eq_MapsIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationMapsIns[0],2)))
print("The linear regression line equation is " + line_eq_MapsIns)

ax[7,1].scatter(xentIns,yent, color = 'red')
ax[7,1].set_title("(Entertainment) App Installs v Rating")
ax[7,1].set_xlabel("App Installs")
ax[7,1].set_ylabel("App Rating")
correlationEntertainmentIns = st.pearsonr(xentIns,yent)
m, b = np.polyfit(xentIns, yent, 1)
ax[7,1].plot(xentIns, m*xentIns + b)
line_eq_EntertainmentIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationEntertainmentIns[0],2)))
print("The linear regression line equation is " + line_eq_EntertainmentIns)

ax[7,2].scatter(xfoodIns,yfood, color = 'red')
ax[7,2].set_title("(Food and Drink)) App Installs v Rating")
ax[7,2].set_xlabel("App Installs")
ax[7,2].set_ylabel("App Rating")
correlationFoodIns = st.pearsonr(xfoodIns,yfood)
m, b = np.polyfit(xfoodIns, yfood, 1)
ax[7,2].plot(xfoodIns, m*xfoodIns + b)
line_eq_FoodIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationFoodIns[0],2)))
print("The linear regression line equation is " + line_eq_FoodIns)


ax[8,0].scatter(xautoIns,yauto, color = 'red')
ax[8,0].set_title("(Auto and Vehicles) App Installs v Rating")
ax[8,0].set_xlabel("App Installs")
ax[8,0].set_ylabel("App Rating")
correlationAutoIns = st.pearsonr(xautoIns,yauto)
m, b = np.polyfit(xautoIns, yauto, 1)
ax[8,0].plot(xautoIns, m*xautoIns + b)
line_eq_AutoIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationAutoIns[0],2)))
print("The linear regression line equation is " + line_eq_AutoIns)

ax[8,1].scatter(xlibraryIns,ylibrary, color = 'red')
ax[8,1].set_title("(Libraries and Demo) App Installs v Rating")
ax[8,1].set_xlabel("App Installs")
ax[8,1].set_ylabel("App Rating")
correlationLibraryIns = st.pearsonr(xlibraryIns,ylibrary)
m, b = np.polyfit(xlibraryIns, ylibrary, 1)
ax[8,1].plot(xlibraryIns, m*xlibraryIns + b)
line_eq_LibraryIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationLibraryIns[0],2)))
print("The linear regression line equation is " + line_eq_LibraryIns)

ax[8,2].scatter(xartIns,yart, color = 'red')
ax[8,2].set_title("(Art and Design) App Installss v Rating")
ax[8,2].set_xlabel("App Installs")
ax[8,2].set_ylabel("App Rating")
correlationArtIns = st.pearsonr(xartIns,yart)
m, b = np.polyfit(xartIns, yart, 1)
ax[8,2].plot(xartIns, m*xartIns + b)
line_eq_ArtIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationArtIns[0],2)))
print("The linear regression line equation is " + line_eq_ArtIns)


ax[9,0].scatter(xhouseIns,yhouse, color = 'red')
ax[9,0].set_title("(House and Home) App Installs v Rating")
ax[9,0].set_xlabel("App Installs")
ax[9,0].set_ylabel("App Rating")
correlationHouseIns = st.pearsonr(xhouseIns,yhouse)
m, b = np.polyfit(xhouseIns, yhouse, 1)
ax[9,0].plot(xhouseIns, m*xhouseIns + b)
line_eq_HouseIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationHouseIns[0],2)))
print("The linear regression line equation is " + line_eq_HouseIns)

ax[9,1].scatter(xweatherIns,yweather, color = 'red')
ax[9,1].set_title("(Weather) App Installs v Rating")
ax[9,1].set_xlabel("App Installs")
ax[9,1].set_ylabel("App Rating")
correlationWeatherIns = st.pearsonr(xweatherIns,yweather)
m, b = np.polyfit(xweatherIns, yweather, 1)
ax[9,1].plot(xweatherIns, m*xweatherIns + b)
line_eq_WeatherIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationWeatherIns[0],2)))
print("The linear regression line equation is " + line_eq_WeatherIns)

ax[9,2].scatter(xcomicIns,ycomic, color = 'red')
ax[9,2].set_title("(Comic) App Installs v Rating")
ax[9,2].set_xlabel("App Installs")
ax[9,2].set_ylabel("App Rating")
correlationComicIns = st.pearsonr(xcomicIns,ycomic)
m, b = np.polyfit(xcomicIns, ycomic, 1)
ax[9,2].plot(xcomicIns, m*xcomicIns + b)
line_eq_ComicIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationComicIns[0],2)))
print("The linear regression line equation is " + line_eq_ComicIns)


ax[10,0].scatter(xparentIns,yparent, color = 'red')
ax[10,0].set_title("(Parenting) App Installs v Rating")
ax[10,0].set_xlabel("App Installs")
ax[10,0].set_ylabel("App Rating")
correlationParentIns = st.pearsonr(xparentIns,yparent)
m, b = np.polyfit(xparentIns, yparent, 1)
ax[10,0].plot(xparentIns, m*xparentIns + b)
line_eq_ParentIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationParentIns[0],2)))
print("The linear regression line equation is " + line_eq_ParentIns)

ax[10,1].scatter(xeventIns,yevent, color = 'red')
ax[10,1].set_title("(Event) App Installs v Rating")
ax[10,1].set_xlabel("App Installs")
ax[10,1].set_ylabel("App Rating")
correlationEventIns = st.pearsonr(xeventIns,yevent)
m, b = np.polyfit(xeventIns, yevent, 1)
ax[10,1].plot(xeventIns, m*xeventIns + b)
line_eq_EventIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationEventIns[0],2)))
print("The linear regression line equation is " + line_eq_EventIns)

ax[10,2].scatter(xbeautyIns,ybeauty, color = 'red')
ax[10,2].set_title("(Beauty) App Installs v Rating")
ax[10,2].set_xlabel("App Installs")
ax[10,2].set_ylabel("App Rating")
correlationBeautyIns = st.pearsonr(xbeautyIns,ybeauty)
m, b = np.polyfit(xbeautyIns, ybeauty, 1)
ax[10,2].plot(xbeautyIns, m*xbeautyIns + b)
line_eq_BeautyIns = "y = " + str(round(m,2)) + "x + " + str(round(b,2))
print("The correlation coefficient is " + str(round(correlationBeautyIns[0],2)))
print("The linear regression line equation is " + line_eq_BeautyIns)
# Out:
# The correlation coefficient is 0.05
# The linear regression line equation is y = 0.0x + 4.19
# The correlation coefficient is 0.11
# The linear regression line equation is y = 0.0x + 4.26
# The correlation coefficient is 0.11
# The linear regression line equation is y = 0.0x + 4.0
# The correlation coefficient is 0.08
# The linear regression line equation is y = 0.0x + 4.17
# The correlation coefficient is 0.02
# The linear regression line equation is y = 0.0x + 4.09
# The correlation coefficient is 0.09
# The linear regression line equation is y = 0.0x + 4.31
# The correlation coefficient is 0.07
# The linear regression line equation is y = 0.0x + 4.1
# The correlation coefficient is 0.07
# The linear regression line equation is y = 0.0x + 4.19
# The correlation coefficient is 0.04
# The linear regression line equation is y = 0.0x + 4.11
# The correlation coefficient is 0.19
# The linear regression line equation is y = 0.0x + 4.1
# The correlation coefficient is 0.09
# ...
